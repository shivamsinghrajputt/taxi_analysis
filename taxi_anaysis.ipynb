# %%
#import libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import datetime as dt

# %%
#LOAD DATA
data=pd.read_csv('C:\\Users\\hp\\OneDrive\\Desktop\\data\\nyk_txi\\train\\train.csv')

# %%
data
# Out:
#                 id  vendor_id      pickup_datetime     dropoff_datetime  \
# 0        id2875421          2  2016-03-14 17:24:55  2016-03-14 17:32:30
# 1        id2377394          1  2016-06-12 00:43:35  2016-06-12 00:54:38
# 2        id3858529          2  2016-01-19 11:35:24  2016-01-19 12:10:48
# 3        id3504673          2  2016-04-06 19:32:31  2016-04-06 19:39:40
# 4        id2181028          2  2016-03-26 13:30:55  2016-03-26 13:38:10
# ...            ...        ...                  ...                  ...
# 1458639  id2376096          2  2016-04-08 13:31:04  2016-04-08 13:44:02
# 1458640  id1049543          1  2016-01-10 07:35:15  2016-01-10 07:46:10
# 1458641  id2304944          2  2016-04-22 06:57:41  2016-04-22 07:10:25
# 1458642  id2714485          1  2016-01-05 15:56:26  2016-01-05 16:02:39
# 1458643  id1209952          1  2016-04-05 14:44:25  2016-04-05 14:47:43
#
#          passenger_count  pickup_longitude  pickup_latitude  \
# ...

# %%
#data info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1458644 entries, 0 to 1458643
# Data columns (total 11 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   id                  1458644 non-null  object
#  1   vendor_id           1458644 non-null  int64
#  2   pickup_datetime     1458644 non-null  object
#  3   dropoff_datetime    1458644 non-null  object
#  4   passenger_count     1458644 non-null  int64
#  5   pickup_longitude    1458644 non-null  float64
#  6   pickup_latitude     1458644 non-null  float64
#  7   dropoff_longitude   1458644 non-null  float64
#  8   dropoff_latitude    1458644 non-null  float64
#  9   store_and_fwd_flag  1458644 non-null  object
#  10  trip_duration       1458644 non-null  int64
# dtypes: float64(4), int64(3), object(4)
# memory usage: 122.4+ MB

# %%
#filter_data

# %%
data=data.filter(['pickup_datetime','passenger_count','pickup_longitude','pickup_latitude','dropoff_longitude','dropoff_latitude','trip_duration'])

# %%
data
# Out:
#              pickup_datetime  passenger_count  pickup_longitude  \
# 0        2016-03-14 17:24:55                1        -73.982155
# 1        2016-06-12 00:43:35                1        -73.980415
# 2        2016-01-19 11:35:24                1        -73.979027
# 3        2016-04-06 19:32:31                1        -74.010040
# 4        2016-03-26 13:30:55                1        -73.973053
# ...                      ...              ...               ...
# 1458639  2016-04-08 13:31:04                4        -73.982201
# 1458640  2016-01-10 07:35:15                1        -74.000946
# 1458641  2016-04-22 06:57:41                1        -73.959129
# 1458642  2016-01-05 15:56:26                1        -73.982079
# 1458643  2016-04-05 14:44:25                1        -73.979538
#
#          pickup_latitude  dropoff_longitude  dropoff_latitude  trip_duration
# 0              40.767937         -73.964630         40.765602            455
# ...

# %%
#extract date, month, day_name, hour

data['month']=pd.to_datetime(data['pickup_datetime']).dt.month_name()
data['date']=pd.to_datetime(data['pickup_datetime']).dt.day
data['week_day']=pd.to_datetime(data['pickup_datetime']).dt.day_name()
data['pickup_hours']=pd.to_datetime(data['pickup_datetime']).dt.hour

# %%
data
# Out:
#              pickup_datetime  passenger_count  pickup_longitude  \
# 0        2016-03-14 17:24:55                1        -73.982155
# 1        2016-06-12 00:43:35                1        -73.980415
# 2        2016-01-19 11:35:24                1        -73.979027
# 3        2016-04-06 19:32:31                1        -74.010040
# 4        2016-03-26 13:30:55                1        -73.973053
# ...                      ...              ...               ...
# 1458639  2016-04-08 13:31:04                4        -73.982201
# 1458640  2016-01-10 07:35:15                1        -74.000946
# 1458641  2016-04-22 06:57:41                1        -73.959129
# 1458642  2016-01-05 15:56:26                1        -73.982079
# 1458643  2016-04-05 14:44:25                1        -73.979538
#
#          pickup_latitude  dropoff_longitude  dropoff_latitude  trip_duration  \
# 0              40.767937         -73.964630         40.765602            455
# ...

# %%
#analysis in which date maximun and least use of taxis.

sns.countplot(data=data, x='date')
plt.show()

# %%
#weak_day analysis...

sns.countplot(data=data, x='week_day')
plt.show()

#friday and saturday used maximum nunmbers of taxis....

# %%
#analysis on months.....

sns.countplot(data=data, x='month')
plt.show()

#in march used maximun no. of taxis...

# %%
#nalysis over time, in which time taxis use maximum....
sns.countplot(data=data,x='pickup_hours')
plt.show()

print('At which time more taxis are used:\n',data['pickup_hours'].mode())

#from 4-5 time taxi use least and 18-19 time  used most.
# Out:
# At which time more taxis are used:
#  0    18
# Name: pickup_hours, dtype: int64

# %% [markdown]
# trip_duration

# %%
#trip duration convert into minutes...

data['trip_duration']= data['trip_duration']/60

# %%
data['trip_duration']= data['trip_duration'].round()

# %%
data
# Out:
#              pickup_datetime  passenger_count  pickup_longitude  \
# 0        2016-03-14 17:24:55                1        -73.982155
# 1        2016-06-12 00:43:35                1        -73.980415
# 2        2016-01-19 11:35:24                1        -73.979027
# 3        2016-04-06 19:32:31                1        -74.010040
# 4        2016-03-26 13:30:55                1        -73.973053
# ...                      ...              ...               ...
# 1458639  2016-04-08 13:31:04                4        -73.982201
# 1458640  2016-01-10 07:35:15                1        -74.000946
# 1458641  2016-04-22 06:57:41                1        -73.959129
# 1458642  2016-01-05 15:56:26                1        -73.982079
# 1458643  2016-04-05 14:44:25                1        -73.979538
#
#          pickup_latitude  dropoff_longitude  dropoff_latitude  trip_duration  \
# 0              40.767937         -73.964630         40.765602            8.0
# ...

# %%
#description of time duration....

data['trip_duration'].describe().round(2)
# Out:
# count    1458644.00
# mean          15.99
# std           87.29
# min            0.00
# 25%            7.00
# 50%           11.00
# 75%           18.00
# max        58771.00
# Name: trip_duration, dtype: float64

# %%
#pickup zone -- where we have to stand more taxis ......

# %%
data.plot(x="pickup_longitude", y="pickup_latitude", kind="scatter")
plt.show()

# %%
#dropoff_zone

data.plot(x="dropoff_longitude", y="dropoff_latitude", kind="scatter")
plt.show()

# %%
#number of personal travel in taxis.....

sns.countplot(data=data, x='passenger_count')
plt.show()

#single person use maximum.....
